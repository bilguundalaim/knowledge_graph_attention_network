# %%
import pandas as pd

# %%
df = pd.read_excel('../excel-files/service.xlsx')
df
# Out:
#                          _id  \
# 0   6760f6be2d480450bb5a3a28
# 1   675aa7a72d480450bb5a393a
# 2   674e63dae312e35893e69338
# 3   673aa70b45d45722ab983133
# 4   673aa6b845d45722ab983131
# ..                       ...
# 95  662f7c30b60ad733f0eec025
# 96  662c98f83682377994da6528
# 97  6629fe863682377994da650a
# 98  66221c2373668d38ab0d3158
# 99  662219fe73668d38ab0d3151
#
#                                                  name  \
# 0   Төрийн аудитын байгууллагын аудитын сэдэвт сан...
# 1                                 Тест үйлчилгээ Эрка
# 2          Тамга, тэмдгийн хяналтын дугаарын лавлагаа
# 3   Төрийн албанд ажиллаж буй албан хаагчийн тодор...
# 4        Төрийн албан хаагчийн цалингийн тодорхойлолт
# ..                                                ...
# 95                             Дүрс оношилгооны зураг
# 96                                ЭМД-ын төлбөр төлөх
# 97  (Дархан-Уул аймаг) Гадаад харилцааны яаманд су...
# 98  Газрын тосны бүтээгдэхүүний агуулахын галын аю...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   _id          100 non-null    object
#  1   name         100 non-null    object
#  2   govAgencyId  100 non-null    object
#  3   serviceType  100 non-null    object
#  4   stageType    100 non-null    object
#  5   createdDate  100 non-null    datetime64[ns]
#  6   deleted      100 non-null    bool
#  7   description  30 non-null     object
# dtypes: bool(1), datetime64[ns](1), object(6)
# memory usage: 5.7+ KB
